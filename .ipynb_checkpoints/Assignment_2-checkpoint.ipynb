# %%
# !pip install selenium
import re
import pandas as pd
from selenium import webdriver
chrome_path = r'C:/Users/garga/Downloads/chromedriver_win32/chromedriver'

# %%
driver = webdriver.Chrome(chrome_path)  # This will open up a chrome window
output = "C://Users//garga//Desktop//Text Analytics//Assignment2//Data"

# %% [markdown]
# ### Problem 1

# %%
def scraper(url,xpath,csv_name):
    
    cmt = []
    for i in range (530,703):
        driver.get(url.format(i))
        driver.find_element_by_xpath(xpath)
        comments = driver.find_elements_by_class_name('Comment')
        for comment in comments:
            cmt.append(comment.text)
        print (i)
        
    user_ID = pd.Series(cmt).apply(lambda x: re.findall('(\w+)\s',x)[0])
    date = pd.Series(cmt).apply(lambda x: re.findall('.*\n(.*)\n?',x)[0])
    comment = pd.Series(cmt).apply(lambda x: ' '.join(re.findall('.*\n.*\n(.*)',x)))
    
    global edmunds_forum
    edmunds_forum = pd.concat([user_ID, date, comment], axis=1)
    edmunds_forum.columns = ['user_ID', 'date', 'message']
    edmunds_forum.to_csv(r'{}//{}.csv'.format(output,csv_name))

# %% [markdown]
# ### Problem 2

# %%
url = "https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p{}"
xpath = """//*[@id="Content"]/div[4]/div[1]/ul"""
csv_name = "problem1b"

scraper(url,xpath,csv_name)
# Out:
# 530
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 557
# 558
# 559
# 560
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 589
# 590
# 591
# 592
# 593
# 594
# 595
# 596
# 597
# 598
# 599
# 600
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# 635
# 636
# 637
# 638
# 639
# 640
# 641
# 642
# 643
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# 651
# 652
# 653
# 654
# 655
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# 672
# 673
# 674
# 675
# 676
# 677
# 678
# 679
# 680
# 681
# 682
# 683
# 684
# 685
# 686
# 687
# 688
# 689
# 690
# 691
# 692
# 693
# 694
# 695
# 696
# 697
# 698
# 699
# 700
# 701
# 702

# %% [markdown]
# ### Problem 3

# %%
model_brand = pd.read_csv(r'C:\Users\garga\Desktop\Text Analytics\Assignment2\Data\models.csv',encoding = 'cp1252')
brand_dict = dict(zip(model_brand.iloc[:,1], model_brand.iloc[:,0]))
discussions = edmunds_forum['message']
def repl(text):
    words = text.split()
    final_string = ' '.join(str(brand_dict.get(word, word)) for word in words)
    return final_string
    
replaced_brands = pd.DataFrame(discussions.map(repl))

#count the brands
brands = model_brand.iloc[:,0].unique()
brands_r = pd.Series(brands).replace(['hyundai,','hyundai.','kia,','kia.','nissan.','toyata','volkwagen']
                                     ,['hyundai','hyundai','kia','kia','nissan','toyota','volkswagen']).unique()

for i,brand in enumerate (brands_r):
    find_brand = replaced_brands['message'].apply(lambda x: len(re.findall(brand,x.lower()))>0)
    replaced_brands.insert(loc=i, column=brand, value = find_brand)

brand_frequecy = replaced_brands.sum().apply(lambda x: np.where(type(x)==int,x,'0'))
brand_frequecy.astype(int).sort_values(ascending= False)[1:11]
# Out:
# bmw         1196
# audi         845
# acura        573
# sedan        278
# seat         269
# honda        269
# infiniti     265
# problem      221
# cadillac     210
# kia          189
# dtype: int32

# %% [markdown]
# ### Lift Values

# %%
replaced_brands = replaced_brands.loc[:, replaced_brands.columns != 'message']
replaced_brands = replaced_brands.loc[:, replaced_brands.columns != 'car']

# %%
import numpy as np

n = len(replaced_brands)
def lift_bw_brands(brand1, brand2):
    a = sum(replaced_brands[brand1])
    b = sum(replaced_brands[brand2])
    c = sum(replaced_brands[brand1]&replaced_brands[brand2])
    
    P_a = np.where(type(a)==int,a,0)/n
    P_b = np.where(type(b)==int,b,0)/n
    P_ab = np.where(type(c)==int,c,0)/n    

    if P_a*P_b != 0:
        lift = P_ab/P_a/P_b
    else:
        lift = np.nan
    return lift

columns = ['brand1','brand2', 'lift']
df_lift = pd.DataFrame(columns=columns)
i = 1
for brand1 in list(replaced_brands):
    for brand2 in list(replaced_brands)[i:]:
        lift = lift_bw_brands(brand1, brand2)
        df_lift = df_lift.append({'brand1':brand1, 'brand2':brand2, 'lift': lift}, ignore_index=True)
    i+=1

# %%
df_lift.sort_values(by = 'lift', ascending = False)
dissimilarity = pd.crosstab(df_lift['brand2'], df_lift['brand1'], 1/df_lift['lift'], aggfunc=np.mean)
dissimilarity
# Out:
# brand1            acura      audi       bmw     buick  cadillac  chevrolet  \
# brand2
# audi           0.487964       NaN       NaN       NaN       NaN        NaN
# bmw            0.744978  0.558724       NaN       NaN       NaN        NaN
# buick          0.751483  0.767221  0.672232       NaN       NaN        NaN
# cadillac       0.388061  0.333362  0.522571  0.145807       NaN        NaN
# chevrolet      0.709598  1.308050  0.925697  0.377709       inf        NaN
# chrysler       0.665248  0.338289  0.816791  0.088526  0.143416        inf
# dodge          1.663119  0.490519  0.991818  0.059017  0.243808   0.185759
# ford           0.627015  0.687564  0.677742  0.193576  0.370227   0.507740
# honda          0.236708  0.563887  1.174587  0.793779  0.607263   1.665635
# hyndai kia          NaN       NaN       NaN       NaN       NaN        NaN
# hyundai        0.434259  0.749736  0.887913  0.443808  0.545666        inf
# infiniti       0.299814  0.408765  0.578560  0.312790  0.276107   1.640867
# kia            1.102911  0.264125  0.930621  2.230844  0.511997   0.585139
# lincoln        0.471217  0.416941  0.536483  0.054725  0.115132        inf
# mazda          0.810771  0.683222  0.501419       inf  2.377128   0.362229
# mercedes       0.321348  0.263769  0.329779  0.288340  0.144761        inf
# mercedes benz  0.443498  0.218008  0.308566       inf  0.162539        inf
# mercedes-benz  0.471217  0.277961  0.491776       inf  0.138158        inf
# mercury        0.554373  0.327012  1.157121  0.039345  0.203173        inf
# mitsubishi     0.120954  1.962074       inf       inf  0.487616        inf
# nissan         0.337904  0.523220  0.740557  0.755418  0.650155        inf
# pontiac        0.665248  0.981037  1.388545  0.023607  0.081269        inf
# problem        0.628289  0.508942  0.672957  1.304276  0.280633   0.456140
# saturn         0.221749  0.327012  0.462848       inf  0.081269        inf
# seat           0.634580  0.478078  0.523135  1.058372  0.728715   0.832817
# sedan          0.497147  0.534761  0.494892  0.410168  0.491150   0.430341
# subaru         1.488888  0.904093  1.359617  1.109520  1.909830        inf
# suzuki              NaN       NaN       NaN       NaN       NaN        NaN
# toyota         0.385421  0.542543  0.734520  0.287216  0.211881   0.452012
# volkswagen     0.960913  0.425116  0.859575       inf  0.528251        inf
# volvo          0.461978  0.398796  0.538196  0.147543  0.270898        inf
#
# brand1         chrysler     dodge      ford     honda     ...      mitsubishi  \
# brand2                                                    ...
# audi                NaN       NaN       NaN       NaN     ...             NaN
# bmw                 NaN       NaN       NaN       NaN     ...             NaN
# buick               NaN       NaN       NaN       NaN     ...             NaN
# cadillac            NaN       NaN       NaN       NaN     ...             NaN
# chevrolet           NaN       NaN       NaN       NaN     ...             NaN
# chrysler            NaN       NaN       NaN       NaN     ...             NaN
# dodge          0.034830       NaN       NaN       NaN     ...             NaN
# ford           0.126935  0.190402       NaN       NaN     ...             NaN
# honda          0.520511  0.780766  0.502140       NaN     ...             NaN
# hyndai kia          NaN       NaN       NaN       NaN     ...             NaN
# hyundai        0.363777  0.363777  0.458919  0.698972     ...             NaN
# infiniti       0.307663  0.384578  0.764495  0.218945     ...             NaN
# kia            0.219427  0.365712  0.545243  0.614853     ...             NaN
# lincoln        0.098684  0.074013  0.134868  0.530921     ...             NaN
# mazda               inf       inf  0.337532  0.553634     ...             NaN
# mercedes       0.248162  0.330882  0.678309  0.523573     ...             NaN
# mercedes benz       inf       inf       inf       inf     ...             NaN
# mercedes-benz       inf       inf  0.269737  0.294956     ...             NaN
# mercury        0.116099  0.058050  0.105779  0.520511     ...             NaN
# mitsubishi          inf       inf       inf       inf     ...             NaN
# nissan         0.371517  0.371517  0.406192  0.370141     ...        0.014861
# pontiac        0.034830       inf  0.047601       inf     ...             inf
# problem        0.366541  0.641447  0.584430  0.676664     ...        0.256579
# saturn         0.023220       inf  0.063467       inf     ...             inf
# seat           1.041022  0.520511  0.776034  0.583406     ...        0.624613
# sedan          1.075851  0.806889  0.441099  0.535933     ...             inf
# subaru         1.091331  0.545666  0.372872  2.446401     ...             inf
# suzuki              NaN       NaN       NaN       NaN     ...             NaN
# toyota         0.169505       inf  0.193047  0.131025     ...        0.169505
# volkswagen          inf  0.150929  0.206269  1.353328     ...             inf
# volvo          0.232198       inf  1.057792  1.301277     ...             inf
#
# brand1           nissan   pontiac   problem    saturn      seat     sedan  \
# brand2
# audi                NaN       NaN       NaN       NaN       NaN       NaN
# bmw                 NaN       NaN       NaN       NaN       NaN       NaN
# buick               NaN       NaN       NaN       NaN       NaN       NaN
# cadillac            NaN       NaN       NaN       NaN       NaN       NaN
# chevrolet           NaN       NaN       NaN       NaN       NaN       NaN
# chrysler            NaN       NaN       NaN       NaN       NaN       NaN
# dodge               NaN       NaN       NaN       NaN       NaN       NaN
# ford                NaN       NaN       NaN       NaN       NaN       NaN
# honda               NaN       NaN       NaN       NaN       NaN       NaN
# hyndai kia          NaN       NaN       NaN       NaN       NaN       NaN
# hyundai             NaN       NaN       NaN       NaN       NaN       NaN
# infiniti            NaN       NaN       NaN       NaN       NaN       NaN
# kia                 NaN       NaN       NaN       NaN       NaN       NaN
# lincoln             NaN       NaN       NaN       NaN       NaN       NaN
# mazda               NaN       NaN       NaN       NaN       NaN       NaN
# mercedes            NaN       NaN       NaN       NaN       NaN       NaN
# mercedes benz       NaN       NaN       NaN       NaN       NaN       NaN
# mercedes-benz       NaN       NaN       NaN       NaN       NaN       NaN
# mercury             NaN       NaN       NaN       NaN       NaN       NaN
# mitsubishi          NaN       NaN       NaN       NaN       NaN       NaN
# nissan              NaN       NaN       NaN       NaN       NaN       NaN
# pontiac             inf       NaN       NaN       NaN       NaN       NaN
# problem        0.304094  0.256579       NaN       NaN       NaN       NaN
# saturn              inf       inf       inf       NaN       NaN       NaN
# seat           0.475896  0.312307  0.605436       inf       NaN       NaN
# sedan          0.573787  0.322755  0.990680  0.107585  0.452194       NaN
# subaru         1.164087  0.109133  0.574248  0.036378  0.815467  0.459682
# suzuki              NaN       NaN       NaN       NaN       NaN       NaN
# toyota         0.090402  0.042376  0.520285       inf  0.633288  0.981714
# volkswagen          inf       inf  1.111842       inf  0.338332  0.699303
# volvo          0.619195       inf  0.475146       inf  0.578345  0.597695
#
# brand1           subaru    toyota  volkswagen
# brand2
# audi                NaN       NaN         NaN
# bmw                 NaN       NaN         NaN
# buick               NaN       NaN         NaN
# cadillac            NaN       NaN         NaN
# chevrolet           NaN       NaN         NaN
# chrysler            NaN       NaN         NaN
# dodge               NaN       NaN         NaN
# ford                NaN       NaN         NaN
# honda               NaN       NaN         NaN
# hyndai kia          NaN       NaN         NaN
# hyundai             NaN       NaN         NaN
# infiniti            NaN       NaN         NaN
# kia                 NaN       NaN         NaN
# lincoln             NaN       NaN         NaN
# mazda               NaN       NaN         NaN
# mercedes            NaN       NaN         NaN
# mercedes benz       NaN       NaN         NaN
# mercedes-benz       NaN       NaN         NaN
# mercury             NaN       NaN         NaN
# mitsubishi          NaN       NaN         NaN
# nissan              NaN       NaN         NaN
# pontiac             NaN       NaN         NaN
# problem             NaN       NaN         NaN
# saturn              NaN       NaN         NaN
# seat                NaN       NaN         NaN
# sedan               NaN       NaN         NaN
# subaru              NaN       NaN         NaN
# suzuki              NaN       NaN         NaN
# toyota         0.663893       NaN         NaN
# volkswagen          inf       inf         NaN
# volvo          0.454721  0.470846         inf
#
# [31 rows x 29 columns]

# %%
import sklearn.manifold
MDS_cars = sklearn.manifold.MDS(n_components=2, metric=True, n_init=4)

dissimilarity = dissimilarity.replace([np.inf, -np.inf], np.nan)
dissimilarity.fillna(999, inplace=True)
dissimilarity
npos = MDS_cars.fit_transform(dissimilarity)

# from matplotlib import pyplot as plt
# plt.scatter(npos[:, 0], npos[:, 1], color='navy', lw=0,
#             label="target= {0}".format(label))

for label in np.unique(brands_r):
        position=dissimilarity==label
        plt.scatter(npos[:, 0], npos[:, 1], color='navy', lw=0, label="target= {0}".format(label))
