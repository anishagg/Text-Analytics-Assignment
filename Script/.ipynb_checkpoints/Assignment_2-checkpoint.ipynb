# %%
# !pip install selenium
import re
import pandas as pd
from selenium import webdriver
chrome_path = r'C:/Users/garga/Downloads/chromedriver_win32/chromedriver'

# %%
driver = webdriver.Chrome(chrome_path)  # This will open up a chrome window
output = "C://Users//garga//Desktop//Text Analytics//Assignment2//Data"

# %% [markdown]
# ### Problem 1

# %%
def scraper(url,xpath,csv_name):
    
    cmt = []
    for i in range (530,703):
        driver.get(url.format(i))
        driver.find_element_by_xpath(xpath)
        comments = driver.find_elements_by_class_name('Comment')
        for comment in comments:
            cmt.append(comment.text)
        
    user_ID = pd.Series(cmt).apply(lambda x: re.findall('(\w+)\s',x)[0])
    date = pd.Series(cmt).apply(lambda x: re.findall('.*\n(.*)\n?',x)[0])
    comment = pd.Series(cmt).apply(lambda x: ' '.join(re.findall('.*\n.*\n(.*)',x)))
    
    global edmunds_forum
    edmunds_forum = pd.concat([user_ID, date, comment], axis=1)
    edmunds_forum.columns = ['user_ID', 'date', 'message']
    edmunds_forum.to_csv(r'{}//{}.csv'.format(output,csv_name))

# %% [markdown]
# ### Problem 2

# %%
url = "https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p{}"
xpath = """//*[@id="Content"]/div[4]/div[1]/ul"""
csv_name = "problem1b"

scraper(url,xpath,csv_name)
# Out:
# 530
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 557
# 558
# 559
# 560
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 589
# 590
# 591
# 592
# 593
# 594
# 595
# 596
# 597
# 598
# 599
# 600
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# 635
# 636
# 637
# 638
# 639
# 640
# 641
# 642
# 643
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# 651
# 652
# 653
# 654
# 655
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# 672
# 673
# 674
# 675
# 676
# 677
# 678
# 679
# 680
# 681
# 682
# 683
# 684
# 685
# 686
# 687
# 688
# 689
# 690
# 691
# 692
# 693
# 694
# 695
# 696
# 697
# 698
# 699
# 700
# 701
# 702

# %% [markdown]
# ### Problem 3

# %%
import numpy as np
model_brand = pd.read_csv(r'C:\Users\garga\Desktop\Text Analytics\Assignment2\Data\models.csv',encoding = 'cp1252')
model_brand.iloc[:,1] = model_brand.iloc[:,1].map(lambda x: x.lower())
brand_dict = dict(zip(model_brand.iloc[:,1], model_brand.iloc[:,0]))
discussions = edmunds_forum['message']
def repl(text):
    words = text.lower().split()
    final_string = ' '.join(str(brand_dict.get(word.strip('.,;!?'), word)) for word in words)
    return final_string
    
replaced_brands = pd.DataFrame(discussions.map(repl))

#count the brands
brands = model_brand.iloc[:,0].unique()
brands_r = pd.Series(brands).replace(['hyundai,','hyundai.','kia,','kia.','nissan.','toyata','volkwagen','mercedes benz','mercedes-benz']
                                     ,['hyundai','hyundai','kia','kia','nissan','toyota','volkswagen','mercedes','mercedes']).unique()

for i,brand in enumerate (brands_r):
    find_brand = replaced_brands['message'].apply(lambda x: len(re.findall(brand,x.lower()))>0)
    replaced_brands.insert(loc=i, column=brand, value = find_brand)

brand_frequecy = replaced_brands.sum().apply(lambda x: np.where(type(x)==int,x,'0'))
brand_frequecy.astype(int).sort_values(ascending= False)[1:11]
# Out:
# bmw           1238
# audi           998
# acura          598
# honda          379
# volkswagen     364
# infiniti       331
# sedan          278
# seat           269
# ford           267
# hyundai        235
# dtype: int32

# %% [markdown]
# ### Lift Values

# %%
replaced_brands = replaced_brands.loc[:, replaced_brands.columns != 'message']
replaced_brands = replaced_brands.loc[:, replaced_brands.columns != 'car']

# %%
n = len(replaced_brands)
def lift_bw_brands(brand1, brand2):
    a = sum(replaced_brands[brand1])
    b = sum(replaced_brands[brand2])
    c = sum(replaced_brands[brand1]&replaced_brands[brand2])
    
    P_a = np.where(type(a)==int,a,0)/n
    P_b = np.where(type(b)==int,b,0)/n
    P_ab = np.where(type(c)==int,c,0)/n    

    if P_a*P_b != 0:
        lift = P_ab/P_a/P_b
    else:
        lift = np.nan
    return lift

columns = ['brand1','brand2', 'lift']
df_lift = pd.DataFrame(columns=columns)
i = 1
for brand1 in list(replaced_brands):
    for brand2 in list(replaced_brands):
        lift = lift_bw_brands(brand1, brand2)
        df_lift = df_lift.append({'brand1':brand1, 'brand2':brand2, 'lift': lift}, ignore_index=True)
    i+=1

# %%
# df_lift.sort_values(by = 'lift', ascending = False)
dissimilarity = pd.crosstab(df_lift['brand1'], df_lift['brand2'], 1/df_lift['lift'], aggfunc=np.mean)
dissimilarity = dissimilarity[~dissimilarity.index.isin(['hyndai kia'])]
dissimilarity
# df_lift['brand2']
# Out:
# brand2         acura      audi       bmw     buick  cadillac  chevrolet  \
# brand1
# acura       0.115712  0.517850  0.782795  0.586275  0.403126   0.651642
# audi        0.517850  0.193111  0.620966  0.543573  0.389832   0.626149
# bmw         0.782795  0.620966  0.239551  0.700226  0.550458   0.640799
# buick       0.586275  0.543573  0.700226  0.014706  0.158824   0.104902
# cadillac    0.403126  0.389832  0.550458  0.158824  0.041796   0.203279
# chevrolet   0.651642  0.626149  0.640799  0.104902  0.203279   0.020704
# chrysler    1.089055  0.253261  1.321661  0.235294  0.351964   0.276058
# dodge       2.545666  0.849690  0.988148  0.161765  0.459752   0.227748
# ford        0.735598  0.736582  0.710668  0.280462  0.464977   0.263241
# honda       0.272391  0.653475  1.134873  0.928922  0.586687   0.603611
# hyundai     0.533183  0.782434  0.922861  0.493697  0.545666   0.486552
# infiniti    0.348188  0.456571  0.619464  0.304228  0.345859   0.571095
# kia         1.168692  0.322384  0.930564  1.485294  0.562848   0.464697
# lincoln     0.470562  0.420707  0.635331  0.052768  0.141641   0.252593
# mazda       0.875073  0.649069  0.536772       inf  2.528638   0.357889
# mercedes    0.378544  0.337577  0.353917  0.259050  0.195331   0.316086
# mercury     0.636416  0.424845  0.878354  0.040441  0.229876   0.113874
# mitsubishi  0.126231  1.158669       inf       inf  0.501548        inf
# nissan      0.392415  0.579334  0.778541  1.147059  0.652012   0.230705
# pontiac     1.157121  0.643705  0.798504  0.049020  0.104489   0.069014
# problem     0.655702  0.554255  0.696589  0.812500  0.279904   0.457566
# saturn      0.231424  0.386223  0.479102  0.029412  0.083591        inf
# seat        0.648470  0.494733  0.523896  0.988971  0.749536   0.795638
# sedan       0.494892  0.516202  0.504509  0.408824  0.484133   0.523255
# subaru      1.529971  1.094298  1.239416  1.750000  1.243421   2.463816
# suzuki      0.231424  0.257482  0.958204       inf       inf        inf
# toyota      0.511803  0.693994  0.810246  0.241597  0.267028   0.216454
# volkswagen  0.842384  0.342891  1.013914  1.338235  0.894919   0.538313
# volvo       0.505276  0.383297  0.627624  0.214052  0.365015   0.904089
#
# brand2      chrysler     dodge      ford     honda    ...      pontiac  \
# brand1                                                ...
# acura       1.089055  2.545666  0.735598  0.272391    ...     1.157121
# audi        0.253261  0.849690  0.736582  0.653475    ...     0.643705
# bmw         1.321661  0.988148  0.710668  1.134873    ...     0.798504
# buick       0.235294  0.161765  0.280462  0.928922    ...     0.049020
# cadillac    0.351964  0.459752  0.464977  0.586687    ...     0.104489
# chevrolet   0.276058  0.227748  0.263241  0.603611    ...     0.069014
# chrysler    0.030960  0.170279  0.413313  0.617566    ...     0.154799
# dodge       0.170279  0.012771  0.262295  1.613390    ...          inf
# ford        0.413313  0.262295  0.051664  0.631635    ...     0.129160
# honda       0.617566  1.613390  0.631635  0.073336    ...     0.733359
# hyundai     0.727554  0.500193  0.607053  0.861697    ...     0.454721
# infiniti    0.931607  0.528396  0.743514  0.332523    ...     0.640480
# kia         0.063170  0.644930  0.549271  0.548661    ...          inf
# lincoln     0.314757  0.194756  0.210101  0.894698    ...          inf
# mazda       1.873065       inf  0.329019  0.467034    ...          inf
# mercedes    0.708978  0.584907  0.514395  0.559797    ...     0.443111
# mercury     0.170279  0.070240  0.189435  0.403348    ...     0.021285
# mitsubishi       inf       inf       inf       inf    ...          inf
# nissan      0.804954  0.498065  0.503725  0.381347    ...          inf
# pontiac     0.154799       inf  0.129160  0.733359    ...     0.001935
# problem     0.427632  0.940789  0.671633  0.704662    ...     0.427632
# saturn      0.061920       inf  0.103328       inf    ...          inf
# seat        0.694014  0.490767  0.694882  0.680254    ...     0.260255
# sedan       0.860681  0.710062  0.448832  0.522753    ...     0.268963
# subaru      1.228070  0.506579  0.472925  0.872697    ...     0.230263
# suzuki      0.123839       inf       inf  0.293344    ...          inf
# toyota      0.323670  1.468653  0.330076  0.196131    ...     0.111262
# volkswagen  0.118625  1.162152  0.626858  0.556131    ...     0.704334
# volvo       0.675955  1.672988  0.564000  1.921401    ...          inf
#
# brand2       problem    saturn      seat     sedan    subaru    suzuki  \
# brand1
# acura       0.655702  0.231424  0.648470  0.494892  1.529971  0.231424
# audi        0.554255  0.386223  0.494733  0.516202  1.094298  0.257482
# bmw         0.696589  0.479102  0.523896  0.504509  1.239416  0.958204
# buick       0.812500  0.029412  0.988971  0.408824  1.750000       inf
# cadillac    0.279904  0.083591  0.749536  0.484133  1.243421       inf
# chevrolet   0.457566       inf  0.795638  0.523255  2.463816       inf
# chrysler    0.427632  0.061920  0.694014  0.860681  1.228070  0.123839
# dodge       0.940789       inf  0.490767  0.710062  0.506579       inf
# ford        0.671633  0.103328  0.694882  0.448832  0.472925       inf
# honda       0.704662       inf  0.680254  0.522753  0.872697  0.293344
# hyundai     0.591138       inf  1.112000  0.526719  0.901864       inf
# infiniti    1.011043       inf  0.749083  0.378837  1.270285       inf
# kia         0.508127       inf  1.051432  0.603672  1.550439  0.156347
# lincoln     2.608553       inf  3.175116  0.820337  1.404605       inf
# mazda       0.739192       inf  0.419879  0.382877  0.398026       inf
# mercedes    0.890251       inf  0.496654  0.351957  1.757675       inf
# mercury     0.470395       inf  0.572562       inf       inf       inf
# mitsubishi  0.256579       inf  0.624613       inf       inf       inf
# nissan      0.256579       inf  0.507498  0.466202  0.898026       inf
# pontiac     0.427632       inf  0.260255  0.268963  0.230263       inf
# problem     0.042763       inf  0.605436  0.990680  0.636102       inf
# saturn           inf  0.000387       inf  0.107585  0.046053       inf
# seat        0.605436       inf  0.052051  0.452194  0.688231       inf
# sedan       0.990680  0.107585  0.452194  0.053793  0.533443       inf
# subaru      0.636102  0.046053  0.688231  0.533443  0.023026       inf
# suzuki           inf       inf       inf       inf       inf  0.000774
# toyota      0.614720       inf  0.855125  0.773268  1.324013       inf
# volkswagen  0.471691  0.140867  0.574139  0.815854  0.171053  0.281734
# volvo       0.560197       inf  0.681869  0.782981  0.603289       inf
#
# brand2        toyota  volkswagen     volvo
# brand1
# acura       0.511803    0.842384  0.505276
# audi        0.693994    0.342891  0.383297
# bmw         0.810246    1.013914  0.627624
# buick       0.241597    1.338235  0.214052
# cadillac    0.267028    0.894919  0.365015
# chevrolet   0.216454    0.538313  0.904089
# chrysler    0.323670    0.118625  0.675955
# dodge       1.468653    1.162152  1.672988
# ford        0.330076    0.626858  0.564000
# honda       0.196131    0.556131  1.921401
# hyundai     0.275226    0.570754  0.850979
# infiniti    0.433266    0.971394  0.335611
# kia         0.345767    0.139486  1.024071
# lincoln     0.678696    2.148220  0.128854
# mazda       0.384647    0.473469  0.613429
# mercedes    0.363984    0.645170  0.200164
# mercury     0.122388    0.258256       inf
# mitsubishi  0.267028    0.084520       inf
# nissan      0.115712    0.189442  0.659056
# pontiac     0.111262    0.704334       inf
# problem     0.614720    0.471691  0.560197
# saturn           inf    0.140867       inf
# seat        0.855125    0.574139  0.681869
# sedan       0.773268    0.815854  0.782981
# subaru      1.324013    0.171053  0.603289
# suzuki           inf    0.281734       inf
# toyota      0.022252    0.476461  0.971685
# volkswagen  0.476461    0.070433  0.384449
# volvo       0.971685    0.384449  0.025348
#
# [29 rows x 29 columns]

# %%
import sklearn.manifold
MDS_cars = sklearn.manifold.MDS(n_components=2, metric=True, dissimilarity='precomputed')

dissimilarity = dissimilarity.replace([np.inf, -np.inf], np.nan)
dissimilarity.fillna(999, inplace=True)
npos = MDS_cars.fit_transform(dissimilarity)

# %%
from matplotlib import pyplot as plt

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,9))

for label in np.unique(brands_r):
        position=dissimilarity==label
        ax1.scatter(npos[:, 0], npos[:, 1])
for i, txt in enumerate(list(dissimilarity)):
    ax1.annotate(txt, (npos[i, 0], npos[i, 1]), size =14)
    
    
for label in np.unique(brands_r):
        ax2.scatter(npos[:, 0], npos[:, 1])
ax2.set_xlim(-50, 75)
ax2.set_ylim(-25, 75)

for i, txt in enumerate(list(dissimilarity)):
    ax2.annotate(txt, (npos[i, 0], npos[i, 1]), size =14)

# %%
from nltk.corpus import stopwords
comments = pd.DataFrame(discussions.map(repl))
comments['message'].iloc[0]

car_brands = [brand for brand in brands_r if brand not in ['car','seat','sedan','problem']]

def brnd_stt(comment):
    sentence = re.split('[;.?!]',comment.lower())
    stp_removed = [' '.join([word.strip('.,;!?-\(\)') for word in x.split() if word not in stopwords.words('english')]) for x in sentence]
    return [x for x in stp_removed if len(list(set(car_brands).intersection(x.split())))>0]

brand_statement = comments['message'].map(brnd_stt)
brand_statement1 = [x for x in brand_statement if len(x)>0]

# %%
attributes = pd.DataFrame(columns=['brand','features'])

def find_attributes(sentence):
    global attributes
    brand_found = [brand for brand in car_brands if brand in sentence.split()]

    for i in range(0,len(brand_found)):
        idx = sentence.split().index(brand_found[i])
        idx1 = max(0,idx-5)
        idx2 = min(len(sentence.split()),idx+6)
        
        br = brand_found[i]
        features = sentence.split()[idx1:idx2]
        attributes = attributes.append({'brand':br, 'features':features}, ignore_index=True)

[pd.Series(x).map(find_attributes) for x in brand_statement1]
attributes.head()
# Out:
#        brand                                           features
# 0  chevrolet  [like, bsw, feature, two, 2014, chevrolet, imp...
# 1      mazda  [bought, 2012, mazda, mazda, last, year, trim,...
# 2      mazda  [mazda, much, larger, vehicle, looks, classified]
# 3      mazda  [i'm, sure, exactly, systems, work, mazda, cam...
# 4      mazda  [mazda, expanded, functionality, system, 2014,...

# %%
all_attributes = attributes.groupby('brand')['features'].sum()
all_attributes.map(lambda x: [word for word in x if word not in brands_r])
# Out:
# brand
# acura         [shopping, new, earlier, year, 2012, tl, sh-aw...
# audi          [background:, toy, '16, tts, awd, commuter, '1...
# bmw           [saw, couple, drive, event, one, test, driving...
# buick         [overall, think, without, doubt, nicest, i've,...
# cadillac      [today, wide, margin, price, reflects, differe...
# chevrolet     [like, bsw, feature, two, 2014, impala's, chit...
# chrysler      [1, 1, 1, i've, even, looked, 300s, sho, case,...
# dodge         [they've, reduced, lineup, rwd, base, awd, mod...
# ford          [07, last, november, chose, cx-9, traded, 2007...
# honda         [engine, smooth, not, straight-six, smooth, i-...
# hyundai       [fancier, leather, option:, hardest, one, msrp...
# infiniti      [ended, falling, love, cpo, 2010, m35, sport, ...
# kia           [se, 4-motion, awd, wife's, '16, time, assumin...
# lincoln       [time, entertained, took, new, get, back, deal...
# mazda         [bought, 2012, last, year, trim, level, much, ...
# mercedes      [even, worse, leather, even, expensive, even, ...
# mercury       [said, let's, wait, see, agrees, pay, dv, thin...
# mitsubishi    [tl, '88, integra, '84, mirage, turbo, &, '78,...
# nissan        [earlier, year, short, list, line, versions, 6...
# pontiac       [due, styling, alone, know, happen, giving, us...
# saturn        [laurasdada, said:, vue's, something, could, g...
# subaru        [last, weekend, fell, love, awd, leather, moon...
# suzuki        [sensors, upgraded, tires, uhp, a/s's, guards,...
# toyota        [roundel, could, placed, onto, could, sell, $3...
# volkswagen    [tts, awd, commuter, '17, alltrack, se, 4-moti...
# volvo         [year, short, list, went, dealer, near, house,...
# Name: features, dtype: object

# %%
all_attributes['audi']
# Out:
# ['background:',
#  'toy',
#  "'16",
#  'audi',
#  'tts',
#  'audi',
#  'awd',
#  'commuter',
#  "'17",
#  'say',
#  'least',
#  'certainly',
#  'remotely',
#  'smooth',
#  'audi',
#  '2',
#  '0l',
#  'something',
#  'big',
#  'audi',
#  'would',
#  'work',
#  'like',
#  'audi',
#  'and',
#  'audi',
#  's/c',
#  '3',
#  'montgomery',
#  'twice',
#  '3rd',
#  'attempt',
#  'fix',
#  'audi',
#  '"binding"',
#  'issues',
#  'ipod',
#  'issue',
#  'resolved',
#  'put',
#  'another',
#  'audi',
#  '3',
#  'one',
#  'reasons',
#  'bought',
#  'audi',
#  'years',
#  'ago',
#  'rather',
#  'bmw',
#  'time',
#  '1',
#  'series',
#  'fwd',
#  'competition',
#  'along',
#  'audi',
#  'knows',
#  'used',
#  'audi',
#  'bmw530i',
#  'her',
#  'old',
#  'infiniti',
#  'current',
#  'fwd',
#  'car',
#  'market',
#  'already',
#  'volkswagen',
#  'audi',
#  'like',
#  'audi',
#  'time',
#  'since',
#  "i've",
#  'car',
#  'troublesome',
#  'audi',
#  'though',
#  'pulled',
#  'together',
#  'pitting',
#  'infiniti',
#  'like-priced',
#  'audi',
#  "a4's",
#  'bmw',
#  "3's",
#  'naturally',
#  'infiniti',
#  'wants',
#  'compare',
#  'infiniti',
#  'audi',
#  'bmw',
#  'based',
#  'price',
#  'germans',
#  'seem',
#  '"',
#  'put',
#  'audi',
#  'audi',
#  '2',
#  'bmw',
#  'and',
#  'mb',
#  'audi',
#  'direction',
#  'go',
#  'socio-economically',
#  'hence',
#  '320i',
#  'cla',
#  '1/2-series',
#  'new',
#  'audi',
#  'sedan',
#  '"if',
#  'put',
#  'audi',
#  'audi',
#  '2',
#  '"',
#  'mark',
#  'lately',
#  'leaning',
#  'towards',
#  'audi',
#  'bmw',
#  'simply',
#  'price',
#  'built',
#  "audi's",
#  'segment',
#  'price',
#  '50k',
#  'top',
#  'line',
#  'audi',
#  'comes',
#  '8',
#  'spd',
#  'tiptronic',
#  'great',
#  'think',
#  'audi',
#  'edge',
#  'bmw',
#  'comes',
#  'price',
#  "can't",
#  'issues',
#  's4',
#  'cautious',
#  'pulling',
#  'trigger',
#  'audi',
#  'i',
#  'need',
#  'sedan',
#  'let',
#  'scare',
#  'away',
#  'audi',
#  'since',
#  "i've",
#  'go',
#  'dealership',
#  'much',
#  'audi',
#  'however',
#  'heard',
#  'people',
#  'complaining',
#  'bmw',
#  'or',
#  'audi',
#  'c-class',
#  'small',
#  'inside',
#  'rode',
#  'harsh',
#  'go',
#  'drive',
#  'audi',
#  'audi',
#  'seriously',
#  'doubt',
#  'others',
#  'fwd',
#  'get',
#  'lot',
#  'value',
#  'bang',
#  'buck',
#  'audi',
#  'rotor',
#  'tl',
#  'infiniti',
#  'included',
#  '5',
#  'audi',
#  'and',
#  'even',
#  'low',
#  'cost',
#  'vw',
#  'everything',
#  'else',
#  'ranking',
#  'follows:',
#  '1',
#  'audi',
#  's4',
#  '3',
#  'virtual',
#  'tie',
#  'tl-sh-awd',
#  'honda',
#  'sport',
#  'cvt',
#  'toy',
#  "'16",
#  'audi',
#  'tts',
#  'audi',
#  'awd',
#  'commuter',
#  "'17",
#  '2013',
#  'model',
#  "i'm",
#  'betting',
#  'guessing',
#  'audi',
#  'worked',
#  'kinks',
#  'quirks',
#  '2014',
#  'model',
#  'betting',
#  'lot',
#  'made',
#  'offer',
#  'one',
#  'audi',
#  'dealer',
#  'accepted',
#  'causing',
#  'someone',
#  'get',
#  'ultra',
#  'optioned',
#  'audi',
#  'less',
#  'optioned',
#  's4',
#  'similar',
#  'prices',
#  '$50k',
#  '+',
#  'going',
#  's4',
#  'audi',
#  'agree',
#  "audi's",
#  'bargain',
#  'every',
#  'price',
#  '2013',
#  'model',
#  "i'm",
#  'betting',
#  'guessing',
#  'audi',
#  'worked',
#  'kinks',
#  'quirks',
#  '2014',
#  'model',
#  'san',
#  'diego',
#  'audi',
#  "s5's",
#  'surprised',
#  'know',
#  'track',
#  'audi',
#  "i'm",
#  'sure',
#  'absolute',
#  'blast',
#  's4',
#  'remember',
#  'exact',
#  'numbers',
#  'audi',
#  'supplier',
#  'able',
#  'buy',
#  'car',
#  '6%',
#  'audi',
#  'seem',
#  'rebate',
#  'subsidize',
#  'leases',
#  'like',
#  'btw',
#  'supposedly',
#  'mine',
#  'done',
#  'tomorrow',
#  'audi',
#  'week',
#  'audi',
#  'bmw',
#  'mercedes-benz',
#  'alike',
#  'make',
#  'sell',
#  'cost',
#  'always',
#  'take',
#  'acura',
#  'honda',
#  'audi',
#  'volkswagen',
#  'lexus',
#  'toyota',
#  'infiniti',
#  'nissan',
#  'volkswagen',
#  'quantum',
#  'audi',
#  '4000',
#  'remember',
#  'audi',
#  'believe',
#  'price',
#  'justifies',
#  'premium',
#  '"pedestrian"',
#  'audi',
#  'nice',
#  'car',
#  'see',
#  'premium',
#  'bits',
#  'audi',
#  'volkswagen',
#  'also',
#  'see',
#  'things',
#  'audi',
#  'still',
#  '"binding"',
#  'much',
#  'pain',
#  'first',
#  'and',
#  'only',
#  'new',
#  'audi',
#  'spent',
#  'time',
#  'or',
#  'seemed',
#  'way',
#  'time',
#  'comes',
#  '11',
#  'months',
#  'contain',
#  'audi',
#  'acura',
#  'infiniti',
#  'probably',
#  'volvo',
#  'right',
#  'seems',
#  'something',
#  'like',
#  'audi',
#  'supercharged',
#  'engine',
#  'cross',
#  'audi',
#  'allroad',
#  'hope',
#  'someone',
#  'audi',
#  'reads',
#  'posts',
#  'going',
#  'spend',
#  'large',
#  'amount',
#  'money',
#  'audi',
#  'anyone',
#  'else',
#  'better',
#  'believe',
#  "i'm",
#  'thankfully',
#  'audi',
#  'still',
#  'makes',
#  'enough',
#  'options',
#  'stand-alone',
#  'escondido',
#  'dealer',
#  'needed',
#  '$1k',
#  'sd',
#  'audi',
#  'wanted',
#  '$2,500',
#  'down',
#  'emailed',
#  'offer',
#  'response',
#  'decided',
#  'extend',
#  'offer',
#  'escondido',
#  'audi',
#  'person',
#  'jumped',
#  'after',
#  'couple',
#  'attempts',
#  'bad',
#  'sale-person',
#  'helped',
#  'previously',
#  'sd',
#  'audi',
#  'said',
#  'clients',
#  'day',
#  'long',
#  'get',
#  'audi',
#  'club',
#  'north',
#  'america',
#  'members',
#  'good',
#  'audi',
#  'ownership',
#  'also',
#  'gives',
#  '$1,000',
#  'loyalty',
#  '2014',
#  's4',
#  'audi',
#  'drive',
#  'select',
#  'standard',
#  'exchange',
#  'raising',
#  'think',
#  'audi',
#  'could',
#  'top',
#  'previous',
#  'version',
#  'went',
#  'hoehn',
#  'audi',
#  'carlsbad',
#  '2',
#  'weeks',
#  'ago',
#  'i',
#  'audi',
#  'rejected',
#  '$50k',
#  'offer',
#  'not',
#  'including',
#  'needed',
#  'get',
#  'audi',
#  'agree',
#  'offer',
#  'kept',
#  's4',
#  'within',
#  'like',
#  'audi',
#  's/c',
#  '3',
#  'market',
#  'suv',
#  'audi',
#  'would',
#  'top',
#  'list',
#  'said',
#  'tcompare',
#  'two',
#  'audi',
#  'dealerships',
#  "'burg",
#  'bmw',
#  'dealership',
#  "there's",
#  'guess',
#  'needs',
#  'different',
#  'cable',
#  'like',
#  'audi',
#  'also',
#  'says',
#  'loyalty',
#  'rebate',
#  'comes',
#  'audi',
#  'america',
#  'delivery',
#  'first',
#  'luxury',
#  'dealership',
#  'servicing',
#  'experience',
#  'audi',
#  'they',
#  'used',
#  'give',
#  'free',
#  'maintenance',
#  'longest',
#  'repair',
#  'job',
#  'came',
#  'got',
#  'audi',
#  'loaner',
#  'typical',
#  'old',
#  'audi',
#  'dealership',
#  'feeling',
#  "that's",
#  'miramar',
#  'audi',
#  'know',
#  'audi',
#  'san',
#  'diego',
#  'different',
#  'ratted',
#  'customer',
#  'service',
#  'audi',
#  'surveys',
#  'routinely',
#  'giving',
#  'enterprise',
#  'kia',
#  'heard',
#  'gave',
#  'audi',
#  'sweet',
#  '3',
#  'owned',
#  'including',
#  'couple',
#  'honda',
#  'couple',
#  'audi',
#  'a4s',
#  'remember',
#  'something',
#  'similar',
#  'happened',
#  'audi',
#  '/',
#  'volkswagen',
#  'failing',
#  'coils',
#  'turbo',
#  'toy',
#  "'16",
#  'audi',
#  'tts',
#  'audi',
#  'awd',
#  'commuter',
#  "'17",
#  'camera',
#  'deciding',
#  'factor',
#  'appreciated',
#  'forced',
#  'audi',
#  'audi',
#  'got',
#  'money',
#  'of:',
#  '1',
#  'keeping',
#  'souped',
#  'modified',
#  'audi',
#  'track',
#  'toy',
#  'beat',
#  'death',
#  'dies',
#  'bmw',
#  'audi',
#  'acura',
#  'new',
#  'audi',
#  'picked',
#  'rolling',
#  'wifi',
#  'hotspot',
#  'crying',
#  'bmw',
#  'notorious',
#  'this',
#  'audi',
#  'guilty',
#  'well',
#  'corolla-like',
#  'interior',
#  'cost',
#  'much',
#  'new',
#  'audi',
#  '2',
#  'course',
#  'side',
#  'coin',
#  'audi',
#  'ridiculously',
#  'great',
#  'value',
#  'back',
#  '$30k',
#  'formerly',
#  'audi',
#  'of',
#  'america',
#  'almost',
#  '20',
#  'years',
#  'infiniti',
#  'audi',
#  'run',
#  'making',
#  'think',
#  'bmw',
#  'or',
#  'audi',
#  'german',
#  'infiniti',
#  'audi',
#  'bmw',
#  'too',
#  'seem',
#  'masters',
#  'garnering',
#  'audi',
#  'bmw',
#  'cadillac',
#  'lexus',
#  'even',
#  'kia',
#  'invitees',
#  'anecdotes',
#  'wherein',
#  'q50s',
#  'betters',
#  'audi',
#  'a4&#146',
#  'awd',
#  'q50s',
#  'absolutely',
#  'attest',
#  'worthiness',
#  'audi',
#  '3',
#  'series',
#  'and',
#  'therefore',
#  'ats',
#  'germans',
#  'especially',
#  'audi',
#  'bmw',
#  'somehow',
#  'imbue',
#  'car',
#  'dealerships',
#  'went',
#  'audi',
#  'bmw',
#  'volvo',
#  'drove',
#  'like-priced',
#  '$50k',
#  'supercharged',
#  '2014',
#  'audi',
#  'audi',
#  'pity',
#  'infiniti',
#  'brand',
#  'and',
#  'infiniti',
#  'audi',
#  'bmw-like',
#  'launch',
#  'launch',
#  'designed',
#  'tease',
#  'new',
#  'bmw',
#  '3',
#  'cadillac',
#  'ats',
#  'audi',
#  'audi',
#  'or',
#  'even',
#  's4',
#  'lexus',
#  'bmw',
#  'audi',
#  'yes',
#  'think',
#  'comes',
#  'audi',
#  'liking',
#  'make',
#  'profit',
#  'options',
#  'easy',
#  'someone',
#  'pay',
#  's4',
#  'prices',
#  'audi',
#  'example',
#  'audi',
#  'dealer',
#  'g37x',
#  'er',
#  'q50s(x',
#  'deserves',
#  'compared',
#  'audi',
#  'bmw',
#  'history',
#  'overwhelmingly',
#  '~93+%',
#  'german',
#  'overwhelmingly',
#  'audi',
#  'also',
#  'count',
#  '3',
#  "bmw's",
#  'all',
#  '5',
#  'driving',
#  'schools',
#  '4',
#  'audi',
#  'austria',
#  '1',
#  'bmw',
#  'spartenburg',
#  'bmw"',
#  'never',
#  'once',
#  'find',
#  'either',
#  'audi',
#  'bmw',
#  'dubbed',
#  '"the',
#  'german',
#  'infiniti"',
#  'member',
#  'audi',
#  'club',
#  'na',
#  'least',
#  'motivation',
#  'minimum',
#  'that',
#  'driven',
#  'absolutely',
#  'worth',
#  'compared',
#  'audi',
#  'audi',
#  'bmw',
#  '3',
#  'and',
#  'you',
#  'quotes',
#  'japanese',
#  'bmw',
#  'long',
#  'post',
#  'audi',
#  'discount',
#  'get',
#  'audi',
#  'club',
#  'discount',
#  'car',
#  'assuming',
#  'worthy',
#  'spoken',
#  'breath',
#  'audi',
#  'bmw',
#  'test',
#  'drive',
#  'new',
#  'infiniti',
#  'competition',
#  'audi',
#  '3',
#  'series',
#  'price',
#  'point',
#  'infiniti',
#  'present',
#  'significantly',
#  'higher',
#  'content',
#  'audi',
#  '3',
#  'series',
#  'q50s',
#  'at',
#  'price',
#  'point',
#  'best',
#  'audi',
#  '3',
#  'series',
#  'may',
#  'translate',
#  'new',
#  'infiniti',
#  'bettering',
#  'audi',
#  '3',
#  'series',
#  'enthusiasts',
#  'magazine',
#  'comparo',
#  'brand',
#  'able',
#  'spout',
#  'infiniti',
#  'outgun',
#  'audi',
#  '3',
#  'ats',
#  'given',
#  'monetary',
#  'equalizer',
#  'in',
#  'context',
#  'price',
#  'would',
#  'assume',
#  'audi',
#  's4',
#  's5',
#  'bmw',
#  'bmw',
#  'm4',
#  'quite',
#  'willing',
#  'take',
#  'new',
#  'rs7',
#  'audi',
#  '$50k',
#  'dream',
#  'on',
#  'car',
#  'actually',
#  'and',
#  'yes',
#  'member',
#  'audi',
#  'club',
#  'na',
#  'get',
#  'certificate',
#  'good',
#  'back',
#  'audi',
#  '3',
#  'new',
#  'f',
#  'sport',
#  'asked',
#  's4',
#  'also',
#  'much',
#  'good',
#  'deal',
#  'audi',
#  'as',
#  'know',
#  '19+',
#  'years',
#  'helm',
#  'audi',
#  'america',
#  'great',
#  'job',
#  'typically',
#  'marketing',
#  'wife',
#  'ordered',
#  'new',
#  'audi',
#  'delivery',
#  'estimated',
#  '~75-90',
#  'days',
#  'last',
#  'but',
#  'end',
#  'chose',
#  '$51k',
#  'audi',
#  'similarly',
#  'priced',
#  'bmw',
#  'volvos',
#  'infinitis',
#  'offers',
#  'bsm',
#  'relatively',
#  'cheap',
#  'like',
#  'audi',
#  'volvo',
#  'name',
#  'two',
#  'score',
#  'another',
#  "logo'd",
#  'coffee',
#  'cups',
#  'in',
#  'case',
#  'audi',
#  "wife's",
#  'case',
#  'bmw',
#  '"expensive"',
#  "logo'd",
#  'day',
#  'audi',
#  'sends',
#  'expensive',
#  'brochures',
#  'time',
#  'time',
#  'cts',
#  '2014',
#  'found',
#  'wanting',
#  'new',
#  'audi',
#  's4',
#  'recently',
#  'drove',
#  'audi',
#  '220hp',
#  'four',
#  'cylinder',
#  'thought',
#  'pretty',
#  'design',
#  'put',
#  ...]
